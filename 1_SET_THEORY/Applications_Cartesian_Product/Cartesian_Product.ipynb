# %% [markdown]
# # Applications of Cartesian Products

# %%
import pandas as pd

# %%
# Generate dataset A
data_1 = pd.DataFrame({'A':[3,4],'B':[5,6]})
data_1
# Out:
#    A  B
# 0  3  5
# 1  4  6

# %%
# Generate dataset A
data_2 = pd.DataFrame({'C':[7,8]})
data_2
# Out:
#    C
# 0  7
# 1  8

# %%
#Create Cartesian Product
data_3 = data_1.merge(data_2, how='cross')
data_3
# Out:
#    A  B  C
# 0  3  5  7
# 1  3  5  8
# 2  4  6  7
# 3  4  6  8

# %% [markdown]
# ### Exercises
# Intructions
# 1. Redo the excercises above but this time, show the Cartesian Product for data_2 $x$ data_1.
# 2. There are two csv files provided, use pandas to read the csv files.
# 3. For the first csv file: electronic-card-transactions-july-2023.csv, use the variable name data_1. Slice data_1 so that only the first 50 rows will be used.
# 4. For the first csv file: wholesale-trade-survey-march-2023-quarter.csv, use the variable name data_2. Slice data_2 so that only the first 50 rows will be used.
# 5. Show data_1 $x$ data_2
# 6. Show data_2 $x$ data_1

# %%
data_1 = pd.read_csv('electronic-card-transactions-july-2023.csv')
data_1 = data_1.head(50)
data_1
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0        ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1        ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2        ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3        ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4        ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# 5        ECTA.S19A1  2006.03     33317.4        NaN      F  Dollars
# 6        ECTA.S19A1  2007.03     36422.0        NaN      F  Dollars
# 7        ECTA.S19A1  2008.03     39198.0        NaN      F  Dollars
# 8        ECTA.S19A1  2009.03     40629.4        NaN      F  Dollars
# 9        ECTA.S19A1  2010.03     41815.4        NaN      F  Dollars
# 10       ECTA.S19A1  2011.03     43848.6        NaN      F  Dollars
# 11       ECTA.S19A1  2012.03     47004.9        NaN      F  Dollars
# 12       ECTA.S19A1  2013.03     49188.8        NaN      F  Dollars
# ...

# %%
data_2 = pd.read_csv('wholesale-trade-survey-march-2023-quarter.csv')
data_2 = data_2.head(50)
data_2
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       WTSQ.SFA1CA  1995.03     2368.69         NaN      F  Dollars
# 1       WTSQ.SFA1CA  1995.06     2100.44         NaN      F  Dollars
# 2       WTSQ.SFA1CA  1995.09     2070.21         NaN      F  Dollars
# 3       WTSQ.SFA1CA  1995.12     2284.77         NaN      F  Dollars
# 4       WTSQ.SFA1CA  1996.03     2134.76         NaN      F  Dollars
# 5       WTSQ.SFA1CA  1996.06     2038.45         NaN      F  Dollars
# 6       WTSQ.SFA1CA  1996.09     2031.17         NaN      F  Dollars
# 7       WTSQ.SFA1CA  1996.12     2263.97         NaN      F  Dollars
# 8       WTSQ.SFA1CA  1997.03     1997.05         NaN      F  Dollars
# 9       WTSQ.SFA1CA  1997.06     2025.13         NaN      F  Dollars
# 10      WTSQ.SFA1CA  1997.09     2009.55         NaN      F  Dollars
# 11      WTSQ.SFA1CA  1997.12     2199.21         NaN      F  Dollars
# 12      WTSQ.SFA1CA  1998.03     2081.28         NaN      F  Dollars
# ...

# %%
data_1.merged(data_2, how )
